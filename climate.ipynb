# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
from sqlalchemy.sql import text

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")
conn = engine.connect()

# %%
# reflect an existing database into a new model

# reflect the tables
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# We can view all of the classes that automap found

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
first_row_ms = session.query(Measurement).first()
first_row_ms.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x25fd6966d30>,
#  'id': 1,
#  'tobs': 65.0,
#  'prcp': 0.08,
#  'station': 'USC00519397',
#  'date': '2010-01-01'}

# %%
first_row_st = session.query(Station).first()
first_row_st.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x25fd697f730>,
#  'longitude': -157.8168,
#  'name': 'WAIKIKI 717.2, HI US',
#  'station': 'USC00519397',
#  'elevation': 3.0,
#  'latitude': 21.2716,
#  'id': 1}

# %%
session.query(Station.station).all()
# print(first_row_ms)
# Out:
# [('USC00519397'),
#  ('USC00513117'),
#  ('USC00514830'),
#  ('USC00517948'),
#  ('USC00518838'),
#  ('USC00519523'),
#  ('USC00519281'),
#  ('USC00511918'),
#  ('USC00516128')]

# %% [markdown]
# # Exploratory Climate Analysis

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results

# Calculate the date 1 year ago from the last data point in the database

# Perform a query to retrieve the data and precipitation scores

# Save the query results as a Pandas DataFrame and set the index to the date column

# Sort the dataframe by date

# Use Pandas Plotting with Matplotlib to plot the data

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data

# %%
# Design a query to show how many stations are available in this dataset?
st_count = session.query(Station).count()
print(st_count)
# Out:
# 9

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.
session.query(Measurement.station, func.count(Measurement.station)).group_by(Measurement.station).order_by(Measurement.station.desc()).all()
# Out:
# [('USC00519523', 2669),
#  ('USC00519397', 2724),
#  ('USC00519281', 2772),
#  ('USC00518838', 511),
#  ('USC00517948', 1372),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00513117', 2709),
#  ('USC00511918', 1979)]

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature of the most active station?

session.query(Measurement.tobs, func.max(Measurement.tobs)).filter_by(station='USC00519281').all()
# Out:
# [(85.0, 85.0)]

# %%
lowest_temp=session.query(func.min(Measurement.tobs)).all()
lowest_temp

# %%
highest_temp=session.query(func.max(Measurement.tobs)).all()
highest_temp

# %%
avg_temp=session.query(func.avg(Measurement.tobs)).all()
avg_temp

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram

# %%
highest_num = session.query(Measurement).filter_by(station='USC00519281').count()
print(highest_num)
# Out:
# 2772

# %%
session.query(Measurement.date).order_by(Measurement.date).first()
# Out:
# ('2010-01-01')

# %%
session.query(Measurement.date).order_by(Measurement.date.desc()).first()
# Out:
# ('2017-08-23')

# %%
ok=session.query(Measurement.date).filter_by(station='USC00519281').\
    filter(Measurement.date > '2016-08-23').\
    order_by(Measurement.date).all()
ok
# Out:
# [('2016-08-24'),
#  ('2016-08-25'),
#  ('2016-08-26'),
#  ('2016-08-27'),
#  ('2016-08-28'),
#  ('2016-08-29'),
#  ('2016-08-30'),
#  ('2016-08-31'),
#  ('2016-09-01'),
#  ('2016-09-02'),
#  ('2016-09-03'),
#  ('2016-09-04'),
#  ('2016-09-05'),
#  ('2016-09-06'),
#  ('2016-09-07'),
#  ('2016-09-08'),
#  ('2016-09-09'),
#  ('2016-09-10'),
#  ('2016-09-11'),
#  ('2016-09-12'),
#  ('2016-09-13'),
#  ('2016-09-14'),
#  ('2016-09-15'),
#  ('2016-09-16'),
#  ('2016-09-17'),
#  ('2016-09-18'),
#  ('2016-09-19'),
#  ('2016-09-20'),
#  ('2016-09-21'),
#  ('2016-09-22'),
#  ('2016-09-23'),
#  ('2016-09-24'),
#  ('2016-09-25'),
#  ('2016-09-26'),
#  ('2016-09-27'),
#  ('2016-09-28'),
#  ('2016-09-29'),
#  ('2016-09-30'),
#  ('2016-10-01'),
#  ('2016-10-02'),
#  ('2016-10-03'),
#  ('2016-10-04'),
#  ('2016-10-05'),
#  ('2016-10-06'),
#  ('2016-10-07'),
#  ('2016-10-08'),
#  ('2016-10-09'),
#  ('2016-10-10'),
#  ('2016-10-11'),
#  ('2016-10-12'),
#  ('2016-10-13'),
#  ('2016-10-14'),
#  ('2016-10-15'),
#  ('2016-10-16'),
#  ('2016-10-17'),
#  ('2016-10-18'),
#  ('2016-10-19'),
#  ('2016-10-20'),
#  ('2016-10-21'),
#  ('2016-10-22'),
#  ('2016-10-23'),
#  ('2016-10-24'),
#  ('2016-10-25'),
#  ('2016-10-26'),
#  ('2016-10-27'),
#  ('2016-10-28'),
#  ('2016-10-29'),
#  ('2016-10-30'),
#  ('2016-10-31'),
#  ('2016-11-01'),
#  ('2016-11-02'),
#  ('2016-11-03'),
#  ('2016-11-04'),
#  ('2016-11-05'),
#  ('2016-11-06'),
#  ('2016-11-07'),
#  ('2016-11-08'),
#  ('2016-11-09'),
#  ('2016-11-10'),
#  ('2016-11-11'),
#  ('2016-11-12'),
#  ('2016-11-13'),
#  ('2016-11-14'),
#  ('2016-11-15'),
#  ('2016-11-16'),
#  ('2016-11-17'),
#  ('2016-11-18'),
#  ('2016-11-19'),
#  ('2016-11-20'),
#  ('2016-11-21'),
#  ('2016-11-22'),
#  ('2016-11-23'),
#  ('2016-11-24'),
#  ('2016-11-25'),
#  ('2016-11-26'),
#  ('2016-11-27'),
#  ('2016-11-28'),
#  ('2016-11-29'),
#  ('2016-11-30'),
#  ('2016-12-01'),
#  ('2016-12-02'),
#  ('2016-12-03'),
#  ('2016-12-04'),
#  ('2016-12-05'),
#  ('2016-12-06'),
#  ('2016-12-07'),
#  ('2016-12-08'),
#  ('2016-12-09'),
#  ('2016-12-10'),
#  ('2016-12-11'),
#  ('2016-12-12'),
#  ('2016-12-13'),
#  ('2016-12-14'),
#  ('2016-12-15'),
#  ('2016-12-16'),
#  ('2016-12-17'),
#  ('2016-12-18'),
#  ('2016-12-19'),
#  ('2016-12-20'),
#  ('2016-12-21'),
#  ('2016-12-22'),
#  ('2016-12-23'),
#  ('2016-12-24'),
#  ('2016-12-25'),
#  ('2016-12-26'),
#  ('2016-12-27'),
#  ('2016-12-28'),
#  ('2016-12-29'),
#  ('2016-12-30'),
#  ('2016-12-31'),
#  ('2017-01-01'),
#  ('2017-01-02'),
#  ('2017-01-03'),
#  ('2017-01-04'),
#  ('2017-01-05'),
#  ('2017-01-06'),
#  ('2017-01-07'),
#  ('2017-01-08'),
#  ('2017-01-09'),
#  ('2017-01-10'),
#  ('2017-01-11'),
#  ('2017-01-12'),
#  ('2017-01-13'),
#  ('2017-01-14'),
#  ('2017-01-15'),
#  ('2017-01-16'),
#  ('2017-01-17'),
#  ('2017-01-18'),
#  ('2017-01-19'),
#  ('2017-01-20'),
#  ('2017-01-21'),
#  ('2017-01-22'),
#  ('2017-01-23'),
#  ('2017-01-24'),
#  ('2017-01-25'),
#  ('2017-01-26'),
#  ('2017-01-27'),
#  ('2017-01-28'),
#  ('2017-01-29'),
#  ('2017-01-30'),
#  ('2017-01-31'),
#  ('2017-02-01'),
#  ('2017-02-02'),
#  ('2017-02-03'),
#  ('2017-02-04'),
#  ('2017-02-05'),
#  ('2017-02-06'),
#  ('2017-02-07'),
#  ('2017-02-08'),
#  ('2017-02-09'),
#  ('2017-02-10'),
#  ('2017-02-11'),
#  ('2017-02-12'),
#  ('2017-02-13'),
#  ('2017-02-14'),
#  ('2017-02-15'),
#  ('2017-02-16'),
#  ('2017-02-17'),
#  ('2017-02-18'),
#  ('2017-02-19'),
#  ('2017-02-20'),
#  ('2017-02-21'),
#  ('2017-02-22'),
#  ('2017-02-23'),
#  ('2017-02-24'),
#  ('2017-02-25'),
#  ('2017-02-26'),
#  ('2017-02-27'),
#  ('2017-02-28'),
#  ('2017-03-01'),
#  ('2017-03-02'),
#  ('2017-03-03'),
#  ('2017-03-04'),
#  ('2017-03-05'),
#  ('2017-03-06'),
#  ('2017-03-07'),
#  ('2017-03-08'),
#  ('2017-03-09'),
#  ('2017-03-10'),
#  ('2017-03-11'),
#  ('2017-03-12'),
#  ('2017-03-13'),
#  ('2017-03-14'),
#  ('2017-03-15'),
#  ('2017-03-16'),
#  ('2017-03-17'),
#  ('2017-03-18'),
#  ('2017-03-19'),
#  ('2017-03-20'),
#  ('2017-03-21'),
#  ('2017-03-22'),
#  ('2017-03-23'),
#  ('2017-03-24'),
#  ('2017-03-25'),
#  ('2017-03-26'),
#  ('2017-03-27'),
#  ('2017-03-28'),
#  ('2017-03-29'),
#  ('2017-03-30'),
#  ('2017-03-31'),
#  ('2017-04-01'),
#  ('2017-04-02'),
#  ('2017-04-03'),
#  ('2017-04-04'),
#  ('2017-04-05'),
#  ('2017-04-06'),
#  ('2017-04-07'),
#  ('2017-04-08'),
#  ('2017-04-09'),
#  ('2017-04-10'),
#  ('2017-04-11'),
#  ('2017-04-12'),
#  ('2017-04-13'),
#  ('2017-04-14'),
#  ('2017-04-15'),
#  ('2017-04-16'),
#  ('2017-04-17'),
#  ('2017-04-18'),
#  ('2017-04-19'),
#  ('2017-04-20'),
#  ('2017-04-21'),
#  ('2017-04-22'),
#  ('2017-04-23'),
#  ('2017-04-24'),
#  ('2017-04-25'),
#  ('2017-04-26'),
#  ('2017-04-27'),
#  ('2017-04-28'),
#  ('2017-04-29'),
#  ('2017-04-30'),
#  ('2017-05-01'),
#  ('2017-05-02'),
#  ('2017-05-03'),
#  ('2017-05-04'),
#  ('2017-05-05'),
#  ('2017-05-06'),
#  ('2017-05-07'),
#  ('2017-05-08'),
#  ('2017-05-09'),
#  ('2017-05-10'),
#  ('2017-05-11'),
#  ('2017-05-12'),
#  ('2017-05-13'),
#  ('2017-05-14'),
#  ('2017-05-15'),
#  ('2017-05-16'),
#  ('2017-05-17'),
#  ('2017-05-18'),
#  ('2017-05-19'),
#  ('2017-05-20'),
#  ('2017-05-21'),
#  ('2017-05-22'),
#  ('2017-05-23'),
#  ('2017-05-24'),
#  ('2017-05-25'),
#  ('2017-05-26'),
#  ('2017-05-27'),
#  ('2017-05-28'),
#  ('2017-05-29'),
#  ('2017-05-30'),
#  ('2017-05-31'),
#  ('2017-06-01'),
#  ('2017-06-02'),
#  ('2017-06-03'),
#  ('2017-06-04'),
#  ('2017-06-05'),
#  ('2017-06-06'),
#  ('2017-06-07'),
#  ('2017-06-08'),
#  ('2017-06-09'),
#  ('2017-06-10'),
#  ('2017-06-11'),
#  ('2017-06-12'),
#  ('2017-06-13'),
#  ('2017-06-14'),
#  ('2017-06-15'),
#  ('2017-06-16'),
#  ('2017-06-17'),
#  ('2017-06-18'),
#  ('2017-06-19'),
#  ('2017-06-20'),
#  ('2017-06-21'),
#  ('2017-06-22'),
#  ('2017-06-23'),
#  ('2017-06-24'),
#  ('2017-06-25'),
#  ('2017-06-26'),
#  ('2017-06-27'),
#  ('2017-06-28'),
#  ('2017-06-29'),
#  ('2017-06-30'),
#  ('2017-07-01'),
#  ('2017-07-02'),
#  ('2017-07-03'),
#  ('2017-07-04'),
#  ('2017-07-05'),
#  ('2017-07-06'),
#  ('2017-07-07'),
#  ('2017-07-08'),
#  ('2017-07-09'),
#  ('2017-07-10'),
#  ('2017-07-11'),
#  ('2017-07-12'),
#  ('2017-07-13'),
#  ('2017-07-14'),
#  ('2017-07-15'),
#  ('2017-07-16'),
#  ('2017-07-17'),
#  ('2017-07-18'),
#  ('2017-07-19'),
#  ('2017-07-20'),
#  ('2017-07-21'),
#  ('2017-07-22'),
#  ('2017-07-23'),
#  ('2017-07-24'),
#  ('2017-07-25'),
#  ('2017-07-26'),
#  ('2017-07-27'),
#  ('2017-07-28'),
#  ('2017-07-29'),
#  ('2017-07-30'),
#  ('2017-07-31'),
#  ('2017-08-04'),
#  ('2017-08-05'),
#  ('2017-08-06'),
#  ('2017-08-13'),
#  ('2017-08-14'),
#  ('2017-08-15'),
#  ('2017-08-16'),
#  ('2017-08-17'),
#  ('2017-08-18')]

# %%
session.query(Measurement.date).filter_by(station='USC00519281','').\
     filter(Measurement.date > '2016-08-23').\
     order_by(Measurement.date).all()
# Out:
#   File "<ipython-input-23-cd35a51fddb5>", line 1
#     session.query(Measurement.date).filter_by(station='USC00519281','').\
#                                                                     ^
# SyntaxError: positional argument follows keyword argument

# %%
# mammals = session.query(Measurement).filter(Measurement.date > '2016-08-23').all()
# for Measurement in mammals:
#     print(f"Family: {Measurement.date}, Station: {Measurement.station}")

# %%
session.query(Measurement).all()
# Out:
# [<sqlalchemy.ext.automap.measurement at 0x25fd69663d0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd35af190>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd6641f70>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f1c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f2e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f3a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f4c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f5e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f6a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f7c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f8e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750f9a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750fa00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750fa60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750fac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750fb20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750fb80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750fbe0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750fc40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750fca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750fd00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750fd60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750fdc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750fe20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750fe80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750fee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750ff40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750ffa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd750ffd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75160a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75161c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75162e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75163a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75164c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75165e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75166a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75167c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75168e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75169a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516a00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516a60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516ac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516b20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516b80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516be0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516c40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516ca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516d00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516d60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516dc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516e20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516e80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516ee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516f40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516fa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7516fd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75220a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75221c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75222e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75223a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75224c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75225e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75226a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75227c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75228e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75229a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522a00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522a60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522ac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522b20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522b80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522be0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522c40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522ca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522d00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522d60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522dc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522e20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522e80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522ee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522f40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522fa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7522fd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f0a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f1c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f2e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f3a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f4c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f5e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f6a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f7c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f8e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752f9a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752fa00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752fa60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752fac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752fb20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752fb80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752fbe0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752fc40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752fca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752fd00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752fd60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752fdc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752fe20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752fe80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752fee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752ff40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752ffa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd752ffd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c0a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c1c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c2e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c3a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c4c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c5e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c6a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c7c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c8e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753c9a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753ca00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753ca60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753cac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753cb20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753cb80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753cbe0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753cc40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753cca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753cd00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753cd60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753cdc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753ce20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753ce80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753cee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753cf40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753cfa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd753cfd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75480a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75481c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75482e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75483a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75484c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75485e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75486a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75487c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75488e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75489a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548a00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548a60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548ac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548b20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548b80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548be0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548c40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548ca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548d00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548d60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548dc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548e20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548e80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548ee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548f40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548fa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7548fd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75550a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75551c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75552e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75553a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75554c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75555e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75556a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75557c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75558e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75559a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555a00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555a60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555ac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555b20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555b80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555be0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555c40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555ca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555d00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555d60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555dc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555e20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555e80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555ee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555f40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555fa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7555fd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75630a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75631c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75632e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75633a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75634c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75635e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75636a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75637c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75638e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75639a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563a00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563a60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563ac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563b20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563b80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563be0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563c40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563ca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563d00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563d60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563dc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563e20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563e80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563ee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563f40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563fa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7563fd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d0a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d1c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d2e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d3a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d4c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d5e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d6a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d7c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d8e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756d9a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756da00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756da60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756dac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756db20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756db80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756dbe0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756dc40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756dca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756dd00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756dd60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756ddc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756de20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756de80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756dee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756df40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756dfa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd756dfd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a0a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a1c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a2e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a3a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a4c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a5e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a6a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a7c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a8e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757a9a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757aa00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757aa60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757aac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757ab20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757ab80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757abe0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757ac40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757aca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757ad00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757ad60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757adc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757ae20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757ae80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757aee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757af40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757afa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd757afd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75870a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75871c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75872e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75873a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75874c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75875e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75876a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75877c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75878e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75879a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587a00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587a60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587ac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587b20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587b80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587be0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587c40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587ca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587d00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587d60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587dc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587e20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587e80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587ee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587f40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587fa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7587fd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75940a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75941c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75942e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75943a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75944c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75945e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75946a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75947c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75948e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75949a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594a00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594a60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594ac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594b20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594b80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594be0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594c40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594ca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594d00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594d60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594dc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594e20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594e80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594ee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594f40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594fa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7594fd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a10a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a11c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a12e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a13a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a14c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a15e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a16a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a17c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a18e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a19a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1a00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1a60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1ac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1b20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1b80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1be0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1c40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1ca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1d00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1d60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1dc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1e20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1e80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1ee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1f40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1fa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75a1fd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad0a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad1c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad2e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad3a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad4c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad5e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad6a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad7c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad8e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ad9a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ada00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ada60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75adac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75adb20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75adb80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75adbe0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75adc40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75adca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75add00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75add60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75addc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ade20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ade80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75adee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75adf40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75adfa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75adfd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b80a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b81c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b82e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b83a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b84c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b85e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b86a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b87c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b88e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b89a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8a00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8a60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8ac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8b20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8b80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8be0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8c40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8ca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8d00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8d60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8dc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8e20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8e80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8ee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8f40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8fa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75b8fd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c60a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c61c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c62e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c63a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c64c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c65e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c66a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c67c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c68e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c69a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6a00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6a60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6ac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6b20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6b80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6be0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6c40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6ca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6d00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6d60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6dc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6e20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6e80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6ee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6f40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6fa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75c6fd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d30a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d31c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d32e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d33a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d34c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d35e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d36a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d37c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d38e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d39a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3a00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3a60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3ac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3b20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3b80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3be0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3c40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3ca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3d00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3d60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3dc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3e20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3e80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3ee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3f40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3fa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75d3fd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df0a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df1c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df2e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df3a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df4c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df5e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df6a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df7c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df8e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75df9a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75dfa00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75dfa60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75dfac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75dfb20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75dfb80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75dfbe0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75dfc40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75dfca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75dfd00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75dfd60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75dfdc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75dfe20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75dfe80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75dfee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75dff40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75dffa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75dffd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec0a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec1c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec2e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec3a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec4c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec5e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec6a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec7c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec8e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ec9a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75eca00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75eca60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ecac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ecb20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ecb80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ecbe0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ecc40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ecca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ecd00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ecd60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ecdc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ece20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ece80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ecee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ecf40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ecfa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75ecfd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f80a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f81c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f82e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f83a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f84c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f85e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f86a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f87c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f88e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f89a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8a00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8a60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8ac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8b20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8b80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8be0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8c40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8ca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8d00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8d60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8dc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8e20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8e80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8ee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8f40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8fa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd75f8fd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd76040a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd76041c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd76042e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd76043a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd76044c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd76045e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd76046a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd76047c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd76048e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd76049a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604a00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604a60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604ac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604b20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604b80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604be0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604c40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604ca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604d00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604d60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604dc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604e20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604e80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604ee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604f40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604fa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7604fd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd76110a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd76111c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd76112e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd76113a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd76114c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd76115e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd76116a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd76117c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd76118e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd76119a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611a00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611a60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611ac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611b20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611b80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611be0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611c40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611ca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611d00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611d60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611dc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611e20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611e80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611ee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611f40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611fa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd7611fd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e0a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e1c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e2e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e3a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e4c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e5e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e6a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e7c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e8e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761e9a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761ea00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761ea60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761eac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761eb20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761eb80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761ebe0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761ec40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761eca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761ed00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761ed60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761edc0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761ee20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761ee80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761eee0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761ef40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761efa0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd761efd0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a0a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a100>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a160>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a1c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a220>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a280>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a2e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a340>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a3a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a400>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a460>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a4c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a520>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a580>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a5e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a640>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a6a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a700>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a760>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a7c0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a820>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a880>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a8e0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a940>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762a9a0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762aa00>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762aa60>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762aac0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762ab20>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762ab80>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762abe0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762ac40>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762aca0>,
#  <sqlalchemy.ext.automap.measurement at 0x25fd762ad00>,
#  ...]

# %%
first_row_m1s = session.query(Measurement).first()
first_row_m1s.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x25fd6966d30>,
#  'id': 1,
#  'tobs': 65.0,
#  'prcp': 0.08,
#  'station': 'USC00519397',
#  'date': '2010-01-01'}
